# %% [markdown]
# # import libraries
# - seaborn (it automatically installs following libraries with it)
#
# *numpy*
#
# *scipy*
#
# *pandas*
#
# *matplotlib*

# %%
# import libraries

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load dataset
phool= sns.load_dataset("iris")
phool
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# draw a line plot , line plot should be drawn between two numeric variables
sns.lineplot(x="sepal_length", y="sepal_width", data=phool)

# remember, we mostly plot numericall variables on yaxis and categorical variable on xaxis or in hue, we never take
# numerival varibale in the hue
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
# draw a line plot , line plot should be drawn between two numeric variables
sns.lineplot(x="sepal_length", y="sepal_width", data=phool)
plt.title("Phoolon ka plot")

# you can add title 
plt.title("Phoolon ka plot")

# You can limit the axis limits
plt.xlim(4)
plt.ylim(2)
# Out:
# (2.0, 4.00625)

# %%
# you can change the style of line plot

# draw a line plot , line plot should be drawn between two numeric variables
sns.lineplot(x="sepal_length", y="sepal_width", data=phool)
plt.title("Phoolon ka plot")

# you can add title 
plt.title("Phoolon ka plot")

# You can limit the axis limits
plt.xlim(4)
plt.ylim(2)

sns.set_style("dark") # its not working, figure out why

# %%
# how to set the style to show us dark background

# draw a line plot , line plot should be drawn between two numeric variables
sns.lineplot(x="sepal_length", y="sepal_width", data=phool)
plt.title("Phoolon ka plot")

# you can add title 
plt.title("Phoolon ka plot")

# You can limit the axis limits
plt.xlim(4)
plt.ylim(2)

# set style
sns.set_style("dark")
sns.set_style(style=None, rc=None) # now the background is dark

# %%
## size of figure 
# figure size
plt.figure(figsize=(20,4)) # two values will define the figure size, first valye is x length and second value is y length

# draw a line plot , line plot should be drawn between two numeric variables
sns.lineplot(x="sepal_length", y="sepal_width", data=phool)
plt.title("Phoolon ka plot")

# you can add title 
plt.title("Phoolon ka plot")

# You can limit the axis limits
plt.xlim(4)
plt.ylim(2)
# Out:
# (2.0, 4.00625)
