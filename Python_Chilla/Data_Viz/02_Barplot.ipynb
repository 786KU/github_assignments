# %%
import seaborn as sns
import matplotlib.pyplot as plt

# load dataset
phool= sns.load_dataset("iris")
phool
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# you can add title 
plt.title("Phoolon ka plot")


# draw a bar plot
sns.barplot(x="species", y="sepal_width", data=phool)
plt.title("Phoolon ka plot")
# Out:
# Text(0.5, 1.0, 'Phoolon ka plot')

# %%
# you can add title 
plt.title("Phoolon ka plot")


# draw a bar plot
sns.barplot(x="species", y="sepal_length", data=phool)
plt.title("Phoolon ka plot")
# Out:
# Text(0.5, 1.0, 'Phoolon ka plot')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# # lets load the titanic data to show grouping with barplot

kashti= sns.load_dataset("titanic")
kashti
# draw a bar plot
sns.barplot(x="who", y="alone", hue="sex", data=kashti)
# Out:
# Text(0.5, 1.0, 'Phoolon ka plot')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# # lets load the titanic data to show grouping with barplot

kashti= sns.load_dataset("titanic")
kashti
# draw a bar plot, you can change the order of x-axis man with woman etc., 
sns.barplot(x="who", y="alone", hue="sex", data=kashti, order= ["child","woman", "man"])
# Out:
# Text(0.5, 1.0, 'Phoolon ka plot')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# # lets load the titanic data to show grouping with barplot

kashti= sns.load_dataset("titanic")
kashti
# draw a bar plot,  you can change the order of x-axis man with woman etc.,you can also change the color palette 
sns.barplot(x="who", y="alone", hue="sex", data=kashti, order= ["child","woman", "man"], color="green")
# Out:
# Text(0.5, 1.0, 'Phoolon ka plot')

# %%
# how to remove the error bars?

# these bars are the confidence interval, and when you will set these intervals as none, these will be removed
import seaborn as sns
import matplotlib.pyplot as plt

# # lets load the titanic data to show grouping with barplot

kashti= sns.load_dataset("titanic")
kashti
# draw a bar plot,  you can change the order of x-axis man with woman etc.,you can also change the color palette 
sns.barplot(x="who", y="alone", hue="sex", data=kashti, order= ["child","woman", "man"], color="green", ci=None)
# Out:
# Text(0.5, 1.0, 'Phoolon ka plot')

# %%
# how to remove the error bars?

# these bars are the confidence interval, and when you will set these intervals as none, these will be removed
import seaborn as sns
import matplotlib.pyplot as plt

# # lets load the titanic data to show grouping with barplot

kashti= sns.load_dataset("titanic")
kashti
# draw a bar plot,  you can change the order of x-axis man with woman etc.,you can also change the color palette 
sns.barplot(x="who", y="alone", hue="sex", data=kashti, order= ["child","woman", "man"], color="green", ci=None,
           palette="pastel") # you can search online which type of paleette you want to use
# Out:
# Text(0.5, 1.0, 'Phoolon ka plot')

# %%
# saturation change of color, i.e., intensity change
# how to remove the error bars?

# these bars are the confidence interval, and when you will set these intervals as none, these will be removed
import seaborn as sns
import matplotlib.pyplot as plt

# # lets load the titanic data to show grouping with barplot

kashti= sns.load_dataset("titanic")
kashti
# draw a bar plot,  you can change the order of x-axis man with woman etc.,you can also change the color palette 
sns.barplot(x="who", y="alone", hue="sex", data=kashti, order= ["child","woman", "man"], color="green", ci=None,
           palette="pastel", saturation=0.1) # you can search online which type of paleette you want to use
# Out:
# Text(0.5, 1.0, 'Phoolon ka plot')

# %%
# how to make horizontal bar plot
# you need to make the categorical axis on y-axis instead of xaxis, and numerial axis on the xaxis instead of yaxis
import seaborn as sns
import matplotlib.pyplot as plt

# # lets load the titanic data to show grouping with barplot

kashti= sns.load_dataset("titanic")
kashti
# draw a bar plot,  you can change the order of x-axis man with woman etc.,you can also change the color palette 
sns.barplot(x="alone", y="who", hue="sex", data=kashti, order= ["child","woman", "man"], color="green", ci=None,
           palette="pastel", saturation=1) # you can search online which type of paleette you want to use
# Out:
# <AxesSubplot:xlabel='alone', ylabel='who'>

# %%
# how to make horizontal bar plot
# you need to make the categorical axis on y-axis instead of xaxis, and numerial axis on the xaxis instead of yaxis
import seaborn as sns
import matplotlib.pyplot as plt

# # lets load the titanic data to show grouping with barplot

kashti= sns.load_dataset("titanic")
kashti
# draw a bar plot,  you can change the order of x-axis man with woman etc.,you can also change the color palette 
sns.barplot(x="alone", y="who", hue="sex", data=kashti, linewidth=3, facecolor=(1,.4,.6,1), edgecolor="0.5", errcolor="0.5") # you can search online which type of paleette you want to use
# Out:
# <AxesSubplot:xlabel='alone', ylabel='who'>
